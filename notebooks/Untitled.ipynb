# %%
# !pip install azure-storage-blob azure-identity
from azure.storage.blob import BlobServiceClient
account_url = "https://hamidstockage.blob.core.windows.net"
credential = "E4CoWMUkCZuZS6qWwlQcGIAh4SAxNkl6VG855VoeG5uRzL+OdwUNbzEpJM/X41f4lZYWZ0fnd9fV+AStpxx7dA=="
blob_service_client = BlobServiceClient(account_url, credential=credential)
print("liste des containers")
for containers in blob_service_client.list_containers():
    print(containers.name)
# Out:
# Requirement already satisfied: azure-storage-blob in /opt/conda/lib/python3.13/site-packages (12.30.1)
# Requirement already satisfied: azure-identity in /opt/conda/lib/python3.13/site-packages (1.25.3)
# Requirement already satisfied: azure-core>=1.37.0 in /opt/conda/lib/python3.13/site-packages (from azure-storage-blob) (1.41.0)
# Requirement already satisfied: cryptography>=2.1.4 in /opt/conda/lib/python3.13/site-packages (from azure-storage-blob) (50.0.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/conda/lib/python3.13/site-packages (from azure-storage-blob) (4.16.0)
# Requirement already satisfied: isodate>=0.6.1 in /opt/conda/lib/python3.13/site-packages (from azure-storage-blob) (0.7.2)
# Requirement already satisfied: msal>=1.35.1 in /opt/conda/lib/python3.13/site-packages (from azure-identity) (1.38.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /opt/conda/lib/python3.13/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: requests>=2.21.0 in /opt/conda/lib/python3.13/site-packages (from azure-core>=1.37.0->azure-storage-blob) (2.34.2)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.13/site-packages (from cryptography>=2.1.4->azure-storage-blob) (2.1.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=2.1.4->azure-storage-blob) (3.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /opt/conda/lib/python3.13/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.35.1->azure-identity) (2.13.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-storage-blob) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-storage-blob) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-storage-blob) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-storage-blob) (2026.7.22)
# liste des containers
# clean
# raw
